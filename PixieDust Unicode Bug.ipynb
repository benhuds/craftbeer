# %%
import pandas as pd
import numpy as np

# data from https://www.kaggle.com/nickhould/craft-cans (scraped from CraftCans.com in January 2017)
beers = pd.read_csv("beers.csv")
breweries = pd.read_csv("breweries.csv")

# remove redundant column, rename columns for clarity
beers = beers.drop('Unnamed: 0',axis=1)
breweries = breweries.rename(columns = {'Unnamed: 0': 'brewery_id', 'name': 'brewery_name'})

# merge dataframes, remove NaN values, make ABV more readable, remove leading whitespace
data = pd.merge(beers,breweries,on='brewery_id',how='inner')
data = data[np.isfinite(data['ibu'])]
data['abv'] = data['abv']*100
data['state'] = data['state'].str.slice(1,3)

# filter data only from California
ca = data[data['state'] == 'CA']
pd.set_option('display.max_rows', 500)
ca
# Out:
#       abv    ibu    id                                         name  \
# 21    9.9   92.0  1036                                Lower De Boom
# 22    7.9   45.0  1024                                Fireside Chat
# 24    4.4   42.0   876                              Bitter American
# 25    4.9   17.0   802         Hell or High Watermelon Wheat (2009)
# 26    4.9   17.0   801         Hell or High Watermelon Wheat (2009)
# 27    4.9   17.0   800  21st Amendment Watermelon Wheat Beer (2006)
# 28    7.0   70.0   799                    21st Amendment IPA (2006)
# 29    7.0   70.0   797                 Brew Free! or Die IPA (2008)
# 30    7.0   70.0   796                 Brew Free! or Die IPA (2009)
# 31    8.5   52.0   531         Special Edition: Allies Win The War!
# 32    9.7   94.0   432                                   Hop Crisis
# 33    4.4   42.0   353                       Bitter American (2011)
# 34    7.9   45.0   321                         Fireside Chat (2010)
# 35    6.8   65.0   173                                Back in Black
# 36    8.3   35.0    11                                 Monk's Blood
# 37    7.0   65.0    10                        Brew Free! or Die IPA
# 38    4.9   17.0     9                Hell or High Watermelon Wheat
# 105   5.7   13.0  1520                   Barney Flats Oatmeal Stout
# 106   5.6    4.0  1350                              Summer Solstice
# 107   7.0   80.0  1327                               Hop Ottin' IPA
# 108   5.8   15.0  1326                              Boont Amber Ale
# 109   5.7   13.0  1221                   Barney Flats Oatmeal Stout
# 110   5.5   25.0  1217                       El Steinber Dark Lager
# 111   5.8   15.0   811                       Boont Amber Ale (2010)
# 112   5.6    4.0   753         Summer Solstice Cerveza Crema (2009)
# 113   5.7   13.0   572            Barney Flats Oatmeal Stout (2012)
# 114   6.9    6.0   523                              Winter Solstice
# 115   7.0   80.0   367                        Hop Ottin' IPA (2011)
# 116   5.8   15.0    78                       Boont Amber Ale (2011)
# 117   5.6    4.0    77                       Summer Solstice (2011)
# 118   5.5   28.0    76                 Poleeko Gold Pale Ale (2009)
# 136   5.2   10.0  1172                                    Mo's Gose
# 183   3.8   40.0  2105                                    Even Keel
# 184   5.2   23.0  1401                       Ballast Point Pale Ale
# 185   7.0   75.0  1400                       Big Eye India Pale Ale
# 187   7.0   70.0  1018                                  Sculpin IPA
# 276   4.5   16.0  2412                                    Deception
# 277   7.5   35.0  1898                          Blackmarket Rye IPA
# 278   5.0    8.0  1897                      Black Market Hefeweizen
# 279   5.8   44.0  1896                           Aftermath Pale Ale
# 487   5.6   36.0   668                Mucho Aloha Hawaiian Pale Ale
# 1377                    Mission Brewery            San Diego    CA
# 1385                  Modern Times Beer            San Diego    CA
# 1386                  Modern Times Beer            San Diego    CA
# 1387                  Modern Times Beer            San Diego    CA
# 1388                  Modern Times Beer            San Diego    CA
# 1389                  Modern Times Beer            San Diego    CA
# 1390                  Modern Times Beer            San Diego    CA
# 1391                  Modern Times Beer            San Diego    CA
# 1392                  Modern Times Beer            San Diego    CA
# 1404          Mother Earth Brew Company                Vista    CA
# 1705                     Refuge Brewery             Temecula    CA
# 1777            Ruhstaller Beer Company           Sacramento    CA
# 1778            Ruhstaller Beer Company           Sacramento    CA
# 1779            Ruhstaller Beer Company           Sacramento    CA
# 1780            Ruhstaller Beer Company           Sacramento    CA
# 1781            Ruhstaller Beer Company           Sacramento    CA
# 1782               Saint Archer Brewery            San Diego    CA
# 1783               Saint Archer Brewery            San Diego    CA
# 1784               Saint Archer Brewery            San Diego    CA
# 1785               Saint Archer Brewery            San Diego    CA
# 1807        Santa Cruz Mountain Brewing           Santa Cruz    CA
# 1828                  Seabright Brewery           Santa Cruz    CA
# 1845      Sierra Nevada Brewing Company                Chico    CA
# 1848      Sierra Nevada Brewing Company                Chico    CA
# 1849      Sierra Nevada Brewing Company                Chico    CA
# 1850      Sierra Nevada Brewing Company                Chico    CA
# 1851      Sierra Nevada Brewing Company                Chico    CA
# 1852      Sierra Nevada Brewing Company                Chico    CA
# 1968             Speakasy Ales & Lagers        San Francisco    CA
# 2095                      TailGate Beer            San Diego    CA
# 2097                      TailGate Beer            San Diego    CA
# 2098                      TailGate Beer            San Diego    CA
# 2099                      TailGate Beer            San Diego    CA
# 2100                      TailGate Beer            San Diego    CA
# 2101                      TailGate Beer            San Diego    CA
# 2102                      TailGate Beer            San Diego    CA
# 2156         The Dudes' Brewing Company             Torrance    CA
# 2159         The Dudes' Brewing Company             Torrance    CA
# 2160         The Dudes' Brewing Company             Torrance    CA

# %%
import pixiedust

sqlContext = SQLContext(sc)
ca2 = sqlContext.createDataFrame(ca)

# search table for 'k' and some faulty entries should show up
display(ca2)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-fa3aba6e panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-fa3aba6e" data-parent="#df-table-wrapper-fa3aba6e">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-fa3aba6e" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>struct</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'abv', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'ibu', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'long', 'name': 'id', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'name', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'style', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'long', 'name': 'brewery_id', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'ounces', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'brewery_name', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'city', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'state', 'nullable': True}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-fa3aba6e" data-parent="#df-table-wrapper-fa3aba6e">Table</a>
#       </h4>
#     </div>
#     <div id="df-table-fa3aba6e" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#         <div>
#           <span class="df-table-search-count">Showing 100 of 135</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#               <div class="fixed-cell">abv</div>
#
#               <div class="fixed-cell">ibu</div>
#
#               <div class="fixed-cell">id</div>
#
#               <div class="fixed-cell">name</div>
#
#               <div class="fixed-cell">style</div>
#
#               <div class="fixed-cell">brewery_id</div>
#
#               <div class="fixed-cell">ounces</div>
#
#               <div class="fixed-cell">brewery_name</div>
#
#               <div class="fixed-cell">city</div>
#
#               <div class="fixed-cell">state</div>
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#                 <th><div>abv</div></th>
#
#                 <th><div>ibu</div></th>
#
#                 <th><div>id</div></th>
#
#                 <th><div>name</div></th>
#
#                 <th><div>style</div></th>
#
#                 <th><div>brewery_id</div></th>
#
#                 <th><div>ounces</div></th>
#
#                 <th><div>brewery_name</div></th>
#
#                 <th><div>city</div></th>
#
#                 <th><div>state</div></th>
#
#               </tr>
#             </thead>
#             <tbody>
#
#               <tr>
#
#                 <td>9.9</td>
#
#                 <td>92.0</td>
#
#                 <td>1036</td>
#
#                 <td>Lower De Boom</td>
#
#                 <td>American Barleywine</td>
#
#                 <td>368</td>
#
#                 <td>8.4</td>
#
#                 <td>21st Amendment Brewery</td>
#
#                 <td>San Francisco</td>
#
#                 <td>CA</td>
#
#               </tr>
#
#               <tr>
#
#                 <td>7.9</td>
#
#                 <td>45.0</td>
#
#                 <td>1024</td>
#
#                 <td>Fireside Chat</td>
#
#                 <td>Winter Warmer</td>
#
#                 <td>368</td>
#
#                 <td>12.0</td>
#
#                 <td>21st Amendment Brewery</td>
#
#                 <td>San Francisco</td>
#
#                 <td>CA</td>
#
#               </tr>
#
#               <tr>

# %%
# no bug when importing data directly into pixiedust

df = pixiedust.sampleData("https://raw.githubusercontent.com/benhuds/craftbeer-data/master/ca-data.csv")
display(df)
# Out:
# <style type="text/css">.pd_warning{display:none;}</style><div class="pd_warning"><em>Hey, there's something awesome here! To see it, open this notebook outside GitHub, in a viewer like Jupyter</em></div><style type="text/css" class="pd_save is-viewer-good">
#   .df-table-wrapper .panel-heading {
#     border-radius: 0;
#     padding: 0px;
#   }
#   .df-table-wrapper .panel-heading:hover {
#     border-color: #008571;
#   }
#   .df-table-wrapper .panel-title a {
#     background-color: #f9f9fb;
#     color: #333333;
#     display: block;
#     outline: none;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper .panel-title a:hover {
#     background-color: #337ab7;
#     border-color: #2e6da4;
#     color: #ffffff;
#     display: block;
#     padding: 10px 15px;
#     text-decoration: none;
#   }
#   .df-table-wrapper {
#     font-size: small;
#     font-weight: 300;
#     letter-spacing: 0.5px;
#     line-height: normal;
#   }
#   .df-table-search-count {
#     display: inline-block;
#     margin: 20px 0;
#   }
#   .df-table-container {
#     max-height: 50vh;
#     max-width: 100%;
#     overflow-x: auto;
#     position: relative;
#   }
#   .df-table-wrapper table {
#     border: 0 none #ffffff;
#     border-collapse: collapse;
#     margin: 0;
#     min-width: 100%;
#     padding: 0;
#     table-layout: fixed;
#   }
#   .df-table-wrapper tr.hidden {
#     display: none;
#   }
#   .df-table-wrapper tr:nth-child(even) {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.even {
#     background-color: #f9f9fb;
#   }
#   .df-table-wrapper tr.odd {
#     background-color: #ffffff;
#   }
#   .df-table-wrapper td + td {
#     border-left: 1px solid #e0e0e0;
#   }
#
#   .df-table-wrapper thead,
#   .fixed-header {
#     color: #337ab7;
#     font-family: monospace;
#   }
#   .df-table-wrapper tr,
#   .fixed-row {
#     border: 0 none #ffffff;
#     margin: 0;
#     padding: 0;
#   }
#   .df-table-wrapper th,
#   .df-table-wrapper td,
#   .fixed-cell {
#     border: 0 none #ffffff;
#     margin: 0;
#     min-width: 50px;
#     padding: 5px 20px 5px 10px;
#     text-align: left;
#     word-wrap: break-word;
#   }
#   .df-table-wrapper th {
#     padding-bottom: 0;
#     padding-top: 0;
#   }
#   .df-table-wrapper th div {
#     max-height: 1px;
#     visibility: hidden;
#   }
#
#   .df-schema-field {
#     margin-left: 10px;
#   }
#
#   .fixed-header-container {
#     overflow: hidden;
#     position: relative;
#   }
#   .fixed-header {
#     border-bottom: 2px solid #2e6da4;
#     display: table;
#     position: relative;
#   }
#   .fixed-row {
#     display: table-row;
#   }
#   .fixed-cell {
#     display: table-cell;
#   }
# </style><div class="df-table-wrapper df-table-wrapper-26e70521 panel-group pd_save is-viewer-good">
#   <!-- dataframe schema -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-schema-26e70521" data-parent="#df-table-wrapper-26e70521">Schema</a>
#       </h4>
#     </div>
#     <div id="df-schema-26e70521" class="panel-collapse collapse">
#       <div class="panel-body" style="font-family: monospace;">
#         <div class="df-schema-type">
#           <span>type: </span><span>struct</span>
#         </div>
#         <div class="df-schema-fields">
#           <div>field:</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'integer', 'name': '', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'abv', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'ibu', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'integer', 'name': 'id', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'name', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'style', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'integer', 'name': 'brewery_id', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'ounces', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'brewery_name', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'city', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'state', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'string', 'name': 'city-state', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'latitude', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'double', 'name': 'longitude', 'nullable': True}</div>
#
#             <div class="df-schema-field">{'metadata': {}, 'type': 'boolean', 'name': 'norcal', 'nullable': True}</div>
#
#         </div>
#       </div>
#     </div>
#   </div>
#   <!-- dataframe table -->
#   <div class="panel panel-default">
#     <div class="panel-heading">
#       <h4 class="panel-title" style="margin: 0px;">
#         <a data-toggle="collapse" href="#df-table-26e70521" data-parent="#df-table-wrapper-26e70521">Table</a>
#       </h4>
#     </div>
#     <div id="df-table-26e70521" class="panel-collapse collapse in">
#       <div class="panel-body">
#
#         <input class="df-table-search form-control input-sm" placeholder="Search table" type="text">
#         <div>
#           <span class="df-table-search-count">Showing 100 of 135</span>
#         </div>
#         <!-- fixed header for when dataframe table scrolls -->
#         <div class="fixed-header-container">
#           <div class="fixed-header">
#             <div class="fixed-row">
#
#               <div class="fixed-cell"></div>
#
#               <div class="fixed-cell">abv</div>
#
#               <div class="fixed-cell">ibu</div>
#
#               <div class="fixed-cell">id</div>
#
#               <div class="fixed-cell">name</div>
#
#               <div class="fixed-cell">style</div>
#
#               <div class="fixed-cell">brewery_id</div>
#
#               <div class="fixed-cell">ounces</div>
#
#               <div class="fixed-cell">brewery_name</div>
#
#               <div class="fixed-cell">city</div>
#
#               <div class="fixed-cell">state</div>
#
#               <div class="fixed-cell">city-state</div>
#
#               <div class="fixed-cell">latitude</div>
#
#               <div class="fixed-cell">longitude</div>
#
#               <div class="fixed-cell">norcal</div>
#
#             </div>
#           </div>
#         </div>
#         <div class="df-table-container">
#           <table class="df-table">
#             <thead>
#               <tr>
#
#                 <th><div></div></th>
#
#                 <th><div>abv</div></th>
#
#                 <th><div>ibu</div></th>
#
#                 <th><div>id</div></th>
#
#                 <th><div>name</div></th>
#
#                 <th><div>style</div></th>
#
#                 <th><div>brewery_id</div></th>
#
#                 <th><div>ounces</div></th>
#
#                 <th><div>brewery_name</div></th>
#
#                 <th><div>city</div></th>
#
#                 <th><div>state</div></th>
#
#                 <th><div>city-state</div></th>
#
#                 <th><div>latitude</div></th>
#
#                 <th><div>longitude</div></th>
#
#                 <th><div>norcal</div></th
